# %%
menu_items = {
    # Breakfast Items
    "The Breakfast": [
        {"ingredient": "Baked Beans", "quantity": "80g"},
        {"ingredient": "British Pork Sausage", "quantity": "1"},
        {"ingredient": "Back Bacon", "quantity": "1 rasher"},
        {"ingredient": "Small Free Range Egg", "quantity": "1"},
        {"ingredient": "Hash Browns", "quantity": "2"},
        {"ingredient": "White Farmhouse Bread", "quantity": "1 slice"},
        {"ingredient": "Butter Florette", "quantity": "1"}
    ],
    "Big Breakfast": [
        {"ingredient": "Baked Beans", "quantity": "80g"},
        {"ingredient": "Pork Sausage", "quantity": "2"},
        {"ingredient": "Back Bacon", "quantity": "2 rashers"},
        {"ingredient": "Small Free Range Egg", "quantity": "2"},
        {"ingredient": "Hash Browns", "quantity": "3"},
        {"ingredient": "Tattie Scone", "quantity": "1"}
    ],
    "Vegan Breakfast": [
        {"ingredient": "Baked Beans", "quantity": "80g"},
        {"ingredient": "Medium Avocado", "quantity": "1/2"},
        {"ingredient": "Salad Tomato", "quantity": "1/2"},
        {"ingredient": "Large Flat Mushroom", "quantity": "1"},
        {"ingredient": "Multiseed Batch Bread", "quantity": "1 slice"},
        {"ingredient": "Hash Brown", "quantity": "1"},
        {"ingredient": "Vegan Sausages", "quantity": "2"},
        {"ingredient": "Dairy-Free Flora Portion", "quantity": "1"},
        {"ingredient": "Lime", "quantity": "1/4"}
    ],
    "Breakfast Hash": [
        {"ingredient": "Hash Brown Bites", "quantity": "150g"},
        {"ingredient": "Red Pepper", "quantity": "1/2"},
        {"ingredient": "Spring Onions", "quantity": "10g"},
        {"ingredient": "Fried Egg", "quantity": "1"},
        {"ingredient": "Mixed Baked Beans In Tomato Sauce", "quantity": "1/2 tin"},
        {"ingredient": "Smoked Paprika", "quantity": "2g"}
    ],

    # Baps & Sandwiches
    "Bacon Bap": [
        {"ingredient": "Large White Bap", "quantity": "1"},
        {"ingredient": "Unsalted Butter", "quantity": "10g"},
        {"ingredient": "Back Bacon", "quantity": "2 rashers"}
    ],
    "Sausage Bap": [
        {"ingredient": "Large White Bap", "quantity": "1"},
        {"ingredient": "Unsalted Butter", "quantity": "10g"},
        {"ingredient": "Pork Sausages", "quantity": "2"}
    ],
    "Egg Bap": [
        {"ingredient": "Large White Bap", "quantity": "1"},
        {"ingredient": "Unsalted Butter", "quantity": "10g"},
        {"ingredient": "Fried Egg", "quantity": "1-2"} # Typically 2 depending on prep
    ],
    "Breakfast Muffin": [
        {"ingredient": "English Muffin", "quantity": "1"},
        {"ingredient": "Pork Sausage", "quantity": "1"},
        {"ingredient": "Fried Egg", "quantity": "1"},
        {"ingredient": "Mild Cheese Slice", "quantity": "1"}
    ],
    "Bacon Egg Brioch": [
        {"ingredient": "Brioche Bun", "quantity": "1"},
        {"ingredient": "Fried Egg", "quantity": "1"},
        {"ingredient": "Unsmoked Streaky Bacon", "quantity": "2 rashers"},
        {"ingredient": "Wild Rocket", "quantity": "5g"},
        {"ingredient": "Sweet Chilli Jam", "quantity": "10g"},
        {"ingredient": "Fresh Coriander", "quantity": "2g"},
        {"ingredient": "Light Soft Cheese", "quantity": "35g"},
        {"ingredient": "Crushed Chillies", "quantity": "0.5g"}
    ],

    # On Toast
    "P.Eggs on Toast": [
        {"ingredient": "Bread (White/Wholemeal/Multiseed)", "quantity": "2 slices"},
        {"ingredient": "Unsalted Butter", "quantity": "10g"},
        {"ingredient": "Small Free Range Eggs (Poached)", "quantity": "2"}
    ],
    "F.Eggs on Toast": [
        {"ingredient": "Bread (White/Wholemeal/Multiseed)", "quantity": "2 slices"},
        {"ingredient": "Unsalted Butter", "quantity": "10g"},
        {"ingredient": "Small Free Range Eggs (Fried)", "quantity": "2"}
    ],
    "Avocado on Toast": [
        {"ingredient": "White Sliced Sourdough Loaf", "quantity": "1 slice"},
        {"ingredient": "Medium Avocado", "quantity": "1/2"},
        {"ingredient": "Lime", "quantity": "1/4"},
        {"ingredient": "Salad Tomato", "quantity": "1/2"},
        {"ingredient": "Crushed Chilli Flakes", "quantity": "1g"}
    ],
    "Avo, Feta & Tom": [
        {"ingredient": "White Sourdough Loaf", "quantity": "1 slice"},
        {"ingredient": "Medium Avocado", "quantity": "1/2"},
        {"ingredient": "Lime", "quantity": "1/4"},
        {"ingredient": "Sun Dried Tomatoes", "quantity": "30g"},
        {"ingredient": "Greek Feta Cheese", "quantity": "25g"},
        {"ingredient": "Balsamic Vinegar", "quantity": "10g"}
    ],
    "Avo, Egg & Bacon": [
        {"ingredient": "White Sourdough Loaf", "quantity": "1 slice"},
        {"ingredient": "Medium Avocado", "quantity": "1/2"},
        {"ingredient": "Lime", "quantity": "1/4"},
        {"ingredient": "Unsmoked Streaky Bacon", "quantity": "2 rashers"},
        {"ingredient": "Fried Egg", "quantity": "1"},
        {"ingredient": "Wild Rocket", "quantity": "5g"},
        {"ingredient": "Crushed Chillies", "quantity": "1g"}
    ],
    "Posh Beans": [
        {"ingredient": "Sourdough Loaf", "quantity": "1 slice"},
        {"ingredient": "Five Beanz in Tomato Sauce", "quantity": "1/2 Can"},
        {"ingredient": "BBQ Sauce", "quantity": "15g"},
        {"ingredient": "Poached Egg", "quantity": "1"},
        {"ingredient": "Fresh Cut Coriander", "quantity": "1 sprig"},
        {"ingredient": "Diced Chorizo", "quantity": "25g"}
    ],
    "Shakshuka Eggs": [
        {"ingredient": "White Sourdough Loaf", "quantity": "1 slice"},
        {"ingredient": "Shakshuka Mix", "quantity": "275g (1 pouch)"},
        {"ingredient": "Small Free Range Eggs", "quantity": "2"},
        {"ingredient": "Fresh Cut Coriander", "quantity": "1 sprig"}
    ],

    # Bread / Bakery
    "White Toast Bread": [{"ingredient": "White Farmhouse Bread", "quantity": "2 slices"}, {"ingredient": "Butter", "quantity": "2 florettes"}],
    "Brown Toast Bread": [{"ingredient": "Wholemeal Farmhouse Bread", "quantity": "2 slices"}, {"ingredient": "Butter", "quantity": "2 florettes"}],
    "Multiseed Toast Bread": [{"ingredient": "Multiseed Batch Bread", "quantity": "2 slices"}, {"ingredient": "Butter", "quantity": "2 florettes"}],
    "Sourdough Toast Bread": [{"ingredient": "Sourdough Loaf", "quantity": "2 slices"}, {"ingredient": "Butter", "quantity": "2 florettes"}],
    "Toasted Teacake": [
        {"ingredient": "Teacake", "quantity": "1"},
        {"ingredient": "Butter Florettes", "quantity": "2"},
        {"ingredient": "Jam or Marmalade", "quantity": "20g"}
    ],

    # Mains / Focaccias / Wraps
    "Chicken Burger": [
        {"ingredient": "Chicken Burger Fillet", "quantity": "1"},
        {"ingredient": "Brioche Bun", "quantity": "1"},
        {"ingredient": "Little Gem Lettuce", "quantity": "1 leaf"},
        {"ingredient": "Coleslaw", "quantity": "60g"},
        {"ingredient": "Light Mayonnaise", "quantity": "10g"},
        {"ingredient": "Skin On Fries", "quantity": "200g"},
        {"ingredient": "BBQ Sauce", "quantity": "20g"},
        {"ingredient": "Chip Seasoning", "quantity": "0.5g"}
    ],
    "Chicken Club": [
        {"ingredient": "White Loaf With Sourdough", "quantity": "3 Slices"},
        {"ingredient": "Cooked Chicken Breast Chunks", "quantity": "45g"},
        {"ingredient": "Light Mayonnaise", "quantity": "20g"},
        {"ingredient": "Unsmoked Streaky Bacon", "quantity": "2 Rashers"},
        {"ingredient": "Little Gem Lettuce", "quantity": "2 Leaves"},
        {"ingredient": "Salad Tomatoes", "quantity": "4 Slices"},
        {"ingredient": "Tomato Chutney", "quantity": "20g"},
        {"ingredient": "Skin on Fries", "quantity": "200g"}
    ],
    "Mac and Cheese": [
        {"ingredient": "Mac & Cheese Pouch", "quantity": "1"},
        {"ingredient": "Grated Mozzarella", "quantity": "10g"},
        {"ingredient": "Garlic Bread", "quantity": "1 Slice"},
        {"ingredient": "Freeze Dried Chives", "quantity": "0.5g"}
    ],
    "Fish Finger Wrap": [
        {"ingredient": "Tortilla Wrap", "quantity": "1"},
        {"ingredient": "Omega 3 Fish Fingers", "quantity": "3"},
        {"ingredient": "Little Gem Lettuce", "quantity": "20g"},
        {"ingredient": "Cucumber", "quantity": "30g"},
        {"ingredient": "Tartare Sauce", "quantity": "25ml"},
        {"ingredient": "Babyleaf Salad", "quantity": "15g"},
        {"ingredient": "Cherry Tomatoes", "quantity": "1"}
    ],
    "Honey Chick Wrap": [
        {"ingredient": "Tortilla Wrap", "quantity": "1"},
        {"ingredient": "Chicken Goujons", "quantity": "3 pieces"},
        {"ingredient": "Little Gem Lettuce", "quantity": "2 Leaves"},
        {"ingredient": "Clear Honey", "quantity": "7g"},
        {"ingredient": "Spring Onions", "quantity": "10g"},
        {"ingredient": "Sriracha Hot Chilli Sauce", "quantity": "10g"},
        {"ingredient": "Light Mayonnaise", "quantity": "10g"},
        {"ingredient": "Baby Leaf Salad", "quantity": "15g"},
        {"ingredient": "Cherry Tomatoes", "quantity": "1"}
    ],
    "Chick Flatbread": [
        {"ingredient": "Greek Style Flatbread", "quantity": "1"},
        {"ingredient": "Chicken Burger Fillet", "quantity": "1"},
        {"ingredient": "Streaky Bacon", "quantity": "2 rashers"},
        {"ingredient": "Caesar Dressing", "quantity": "15ml"},
        {"ingredient": "Little Gem Lettuce", "quantity": "20g"},
        {"ingredient": "Parmigiano Reggiano", "quantity": "10g"}
    ],
    "Beef Hors Foca": [
        {"ingredient": "Focaccia Sandwich Loaf", "quantity": "1/4 loaf"},
        {"ingredient": "Wild Rocket", "quantity": "5g"},
        {"ingredient": "Roast Beef Slices", "quantity": "45g"},
        {"ingredient": "Light Mayonnaise", "quantity": "20g"},
        {"ingredient": "Creamed Horseradish", "quantity": "20g"}
    ],
    "NY Deli Foccacia": [
        {"ingredient": "Focaccia Sandwich Loaf", "quantity": "1/4 Loaf"},
        {"ingredient": "Wild Rocket", "quantity": "20g"},
        {"ingredient": "Yellow Squeezy Mustard", "quantity": "5g"},
        {"ingredient": "Light Mayonnaise", "quantity": "10g"},
        {"ingredient": "Salami Slices", "quantity": "3 slices"},
        {"ingredient": "Emmental Slices", "quantity": "1 slice"},
        {"ingredient": "Crinkle Cut Gherkins", "quantity": "20g"}
    ],
    "Fest Plough Foca": [
        {"ingredient": "Focaccia Sandwich Loaf", "quantity": "1/4 loaf"},
        {"ingredient": "Wild Rocket", "quantity": "10g"},
        {"ingredient": "Red Onion Chutney", "quantity": "30g"},
        {"ingredient": "Wensleydale Cheese with Cranberries", "quantity": "32g"},
        {"ingredient": "Mature Cheddar Cheese Slices", "quantity": "2 slices"}
    ],
    "BD Curry Roll": [
        {"ingredient": "Ciabatta Roll", "quantity": "1"},
        {"ingredient": "Light Mayonnaise", "quantity": "25g"},
        {"ingredient": "Curry Powder", "quantity": "3.5g"},
        {"ingredient": "Chicken Slices", "quantity": "40g"},
        {"ingredient": "Little Gem Lettuce", "quantity": "2 leaves"},
        {"ingredient": "Onion Bhaji", "quantity": "1"}
    ],
    "Halloumi Bowl": [
        {"ingredient": "Halloumi", "quantity": "2 Slices"},
        {"ingredient": "Babyleaf Salad", "quantity": "15g"},
        {"ingredient": "Avocado", "quantity": "1/2"},
        {"ingredient": "Pickled Red Cabbage", "quantity": "30g"},
        {"ingredient": "Glorious Grains", "quantity": "125g"},
        {"ingredient": "Houmous", "quantity": "30g"},
        {"ingredient": "Lime", "quantity": "1/2"},
        {"ingredient": "Soya Beans", "quantity": "35g"}
    ],
    "Brie Cranb Tstie": [
        {"ingredient": "Ciabatta roll", "quantity": "1"},
        {"ingredient": "Chicken burger fillet", "quantity": "1"},
        {"ingredient": "Streaky bacon", "quantity": "2 rashers"},
        {"ingredient": "Brie", "quantity": "50g"},
        {"ingredient": "Cranberry sauce", "quantity": "10g"},
        {"ingredient": "Little Gem Lettuce", "quantity": "2 leaves"},
        {"ingredient": "Skin on fries", "quantity": "1 portion"},
        {"ingredient": "Parmesan", "quantity": "10g"}
    ],

    # Base Components / Sides
    "Fried Egg": [{"ingredient": "Free Range Egg", "quantity": "1"}],
    "Poached Egg": [{"ingredient": "Free Range Egg", "quantity": "1"}],
    "Sausage": [{"ingredient": "Pork Sausage", "quantity": "1"}],
    "Bacon": [{"ingredient": "Back Bacon", "quantity": "1 rasher"}],
    "Baked Beans": [{"ingredient": "Baked Beans", "quantity": "80g"}],
    "Kids Beans": [{"ingredient": "Baked Beans", "quantity": "1 portion"}],
    "Kids Sausage": [{"ingredient": "Pork Sausage", "quantity": "1 portion"}],
    "Tattie Scone": [{"ingredient": "Tattie Scone", "quantity": "1"}],
    "Roll & Butter": [{"ingredient": "Bread Roll", "quantity": "1"}, {"ingredient": "Butter", "quantity": "1 portion"}],
    "Streaky Bacon": [{"ingredient": "Streaky Bacon", "quantity": "1 rasher"}],
    "Vegan Sausage": [{"ingredient": "Vegan Sausage", "quantity": "1"}],

    # The following items were requested but explicitly detailed ingredient breakdowns
    # (beyond their basic title) were not featured in the retrieved manual chunks.
    # You can map these to single ingredients or expand them manually.
    "Ham Chse Toastie": [],
    "Chse Onion Tstie": [],
    "Chicken Wrap": [],
    "S.Eggs on Toast": [],
    "Bacon Waffle": [],
    "Cheese Scone": [],
    "Tuna JP": [],
    "Tuna Toastie": [],
    "Lorne Sausage": [],
    "Veggie Breakfast": [],
    "Buttd Mushrooms": [],
    "Black Pudding": [],
    "Ltle Bfast Saus": [],
    "Chilli Carne JP": [],
    "Kids Peas": [],
    "Scrambled Egg": [],
    "Cheese & Bean JP": [],
    "Pig Blank Tstie": [],
    "Festive Stack": [],
    "Chick Rice Bowl": [],
    "Ltle Bfast Bacon": [],
    "Veggie Bap": [],
    "Bean Soldiers": [],
    "Egg Soldiers": [],
    "Cheese JP": [],
    "Baked Beans JP": [],
    "White Bread": [],
    "Extra Tuna": [],
    "Extra Beans": [],
    "Plain JP": []
}
